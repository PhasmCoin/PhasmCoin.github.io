# %% [markdown]
# Connected to Python 3.12.0

# %%
import telebot
bot = telebot.TeleBot("6477130900:AAFUZAmTtsJBjWkkuF7RSl2_4NUDjl6Dreg")
@bot.message_handler(commands=['start'])
def main(message):
    bot.send_message(message.chat.id,"Hello, принцесса")
bot.polling(none_stop=True)
# Out:
# 2024-04-08 17:01:02,829 (__init__.py:1147 MainThread) ERROR - TeleBot: "Threaded polling exception: A request to the Telegram API was unsuccessful. Error code: 409. Description: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"
# 2024-04-08 17:01:02,832 (__init__.py:1149 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "c:\Users\i.fediunin\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\__init__.py", line 1140, in __threaded_polling
#     polling_thread.raise_exceptions()
#   File "c:\Users\i.fediunin\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\util.py", line 110, in raise_exceptions
#     raise self.exception_info
#   File "c:\Users\i.fediunin\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\util.py", line 92, in run
#     task(*args, **kwargs)
# ...
